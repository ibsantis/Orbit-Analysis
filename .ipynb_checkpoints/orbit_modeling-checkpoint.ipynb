# %% [markdown]
# # Satellite Galaxy Orbit Properties

# %% [markdown]
# ****

# %% [markdown]
# ## Imports

# %%
import halo_analysis as halo
import gizmo_analysis as gizmo
import utilities as ut
import orbit_times as ot
import numpy as np
import h5py
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import patches
from scipy.interpolate import interp1d

# %% [markdown]
# ## Introduction
#
# This notebook is dedicated to showcasing the tools used in calculating orbital parameters of satellite galaxies in the FIRE-2 cosmological, hydrodrynamic zoom-in simulations. The orbital properties that these tools can derive include:
# -  First infall time
# -  First pericenter time
# -  Number of pericenters
# -  Pericenter distance
# -  Pericenter velocity
# -  Apocenter distance
# -  Total orbital energy
# -  Orbital angular momentum
# -  Tidal radius
# -  Tidal force
#
# ### Defining Terms
#
# Something something

# %% [markdown]
# ***

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Explain the data here... and print some of it out to show what it is structured like

# %% [markdown]
# ## Section 1: First infall time
